# %% [markdown]
# <a href="https://colab.research.google.com/github/Alinasaghir/yolov5-video-training/blob/main/video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Training video using yolov5 to detect objects

# %%
# !pip install ultralytics -q

# %%
# !yolo detect predict model=yolov8m.pt source="/content/Video17.mp4"
# Out:
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (frame 1/195) /content/Video17.mp4: 640x384 1 person, 1 bicycle, 5 cars, 3 trucks, 973.9ms
# video 1/1 (frame 2/195) /content/Video17.mp4: 640x384 2 persons, 1 bicycle, 7 cars, 3 trucks, 974.0ms
# video 1/1 (frame 3/195) /content/Video17.mp4: 640x384 1 person, 1 bicycle, 7 cars, 2 trucks, 1227.2ms
# video 1/1 (frame 4/195) /content/Video17.mp4: 640x384 1 person, 1 bicycle, 7 cars, 2 trucks, 1874.0ms
# video 1/1 (frame 5/195) /content/Video17.mp4: 640x384 1 person, 3 bicycles, 7 cars, 2 trucks, 1035.6ms
# video 1/1 (frame 6/195) /content/Video17.mp4: 640x384 2 persons, 3 bicycles, 7 cars, 1 bus, 3 trucks, 951.9ms
# video 1/1 (frame 7/195) /content/Video17.mp4: 640x384 2 persons, 2 bicycles, 7 cars, 1 bus, 2 trucks, 951.4ms
# ...
